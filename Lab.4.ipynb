# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, max_value):
        self.__max_value = max_value
        self.__current_value = 0
    def increment(self):
        if self.__current_value < self.__max_value:
            self.__current_value += 1
        else:
            print(f"Error: Counter reached maximum value of {self.__max_value}")
    
    def reset(self):
        self.__current_vlaue = 0
    def get_value(self):
        return self.__current_value
    def get_max(self):
        return self.__max_value
    def is_at_max(self):
        return self.__current_value == self.__max_value

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
c = Counter(2)
c.increment()
print(f"Value: {c.get_value()}")
c.increment()
c.increment()
print(f"Is at max: {c.is_at_max()}")
# Out:
# Value: 1
# Error: Counter reached maximum value of 2
# Is at max: True

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError("Subclass must implement abstract method")
    
    def perimeter(self):
        raise NotImplementedError("Subclass must implement abstract method")
    
    def is_inside(self, x, y):
        raise NotImplementedError("Subclass must implement abstract method")
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_coords(self):
        return (self.__x, self.__y)

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * (self.__radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
import math

class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        raise NotImplementedError("Subclasses must implement area()")

    def perimeter(self):
        raise NotImplementedError("Subclasses must implement perimeter()")


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length = length
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width
    
class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x, y)
        self.__radius = radius

    def area(self):
        return math.pi * (self.__radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

def test_shapes():
    print(" Testing Rectangle ")
    rect = Rectangle(10, 5, 2, 3)
    print(f"Position: ({rect.get_x()}, {rect.get_y()})")
    print(f"Dimensions: {rect.get_length()}x{rect.get_width()}")
    print(f"Area: {rect.area()}")
    print(f"Perimeter: {rect.perimeter()}")

    print("\n Testing Circle ")
    circ = Circle(7, 10, 10)
    print(f"Position: ({circ.get_x()}, {circ.get_y()})")
    print(f"Radius: {circ.get_radius()}")
    print(f"Area: {circ.area():.2f}")
    print(f"Perimeter: {circ.perimeter():.2f}")

    print("\n Polymorphism Test ")
    shapes = [rect, circ]
    for s in shapes:
        print(f"{type(s).__name__} at ({s.get_x()}, {s.get_y()}) has area: {s.area():.2f}")

if __name__ == "__main__":
    test_shapes()
# Out:
#  Testing Rectangle
# Position: (2, 3)
# Dimensions: 10x5
# Area: 50
# Perimeter: 30
#
#  Testing Circle
# Position: (10, 10)
# Radius: 7
# Area: 153.94
# Perimeter: 43.98
#
#  Polymorphism Test
# Rectangle at (2, 3) has area: 50.00
# Circle at (10, 10) has area: 153.94

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base = base
        self.__height = height

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        hypotenuse = math.sqrt(self.__base**2 + self.__height**2)
        return self.__base + self.__height + hypotenuse

    # Accessors
    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height
t = Triangle(10, 5, 0, 0)
print(f"Triangle Area: {t.area()}")
# Out:
# Triangle Area: 25.0

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
def get_perimeter_points(self):
    raise NotImplementedError()

def get_perimeter_points(self):
    points = []
    x, y = self.get_x(), self.get_y()
    w, l = self.get_width(), self.get_length()
    points.append((x, y))
    points.append((x + l, y))
    points.append((x, y + w))
    points.append((x + l, y + w))
    return points

def get_perimeter_points(self):
    points = []
    for i in range(16):
        angle = (2 * math.pi / 16) * i
        px = self.get_x() + self.get_radius() * math.cos(angle)
        py = self.get_y() + self.get_radius() * math.sin(angle)
        points.append((px, py))
    return points

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
def is_inside(self, px, py):
    return (self.get_x() <= px <= self.get_x() + self.get_length() and
            self.get_y() <= py <= self.get_y() + self.get_width())

def is_inside(self, px, py):
    distance = math.sqrt((px - self.get_x())**2 + (py - self.get_y())**2)
    return distance <= self.get_radius()

def is_inside(self, px, py):
    in_x = self.get_x() <= px <= self.get_x() + self.get_base()
    in_y = self.get_y() <= py <= self.get_y() + self.get_height()
    return in_x and in_y

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape(Shape):
    def get_perimeter_points(self):
        return [] 

    def overlaps(self, other_shape):
        points = self.get_perimeter_points()
        for px, py in points:
            if other_shape.is_inside(px, py):
                return True
        return False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
class CompoundShape(Shape):
    def __init__(self, x, y):
        super().__init__(x, y)
        self.__shapes = []

    def add_shape(self, shape):
        self.__shapes.append(shape)

    def paint(self, canvas):
        for shape in self.__shapes:
            shape.paint(canvas)

    def area(self):
        return sum(s.area() for s in self.__shapes)

    def __repr__(self):
        return f"CompoundShape({self.get_x()}, {self.get_y()}, shapes={self.__shapes})"

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def modify_shape(self, index, new_shape):
        if 0 <= index < len(self.shapes):
            self.shapes[index] = new_shape

    def paint(self, canvas):
        canvas.clear()
        for shape in self.shapes:
            shape.paint(canvas)
        print(f"Painted {len(self.shapes)} shapes to the canvas.")

    def __repr__(self):
        return f"RasterDrawing({repr(self.shapes)})"

rd = RasterDrawing()
rd.add_shape(Circle(5, 0, 0))
rd.add_shape(Rectangle(10, 10, 5, 5))

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class RasterDrawing:
    def __init__(self, shapes=None):
        self.shapes = shapes if shapes is not None else []
    def add_shape(self, shape):
        self.shapes.append(shape)
        
    def __repr__(self):
        return f"RasterDrawing({repr(self.shapes)})"
    
    def save(self,filename):
        with open(filename,"w") as f:
            f.write(self.__repr__())
        print(f"Successfully saved to {filename}")
   
def raster_loader(filename):
    with open(filename,"r") as f:
        return eval(f.read())

# %%
# Test
rd_test = RasterDrawing([])
print(repr(rd_test))
# Out:
# RasterDrawing([])

# %%
# Create an object and save it
rd = RasterDrawing()
rd.add_shape(Rectangle(10, 5, 0, 0))
rd.save("Test.drawing")
# Out:
# Successfully saved to Test.drawing

# %%
# Check contents of the saved file
# !cat Test.drawing
# Out:
# RasterDrawing([<__main__.Rectangle object at 0xf51b2c4344a0>])

# %%
# Load the object
rd_reloaded = raster_loader("Test.drawing")
print(rd_reloaded)
# Out:
# Traceback (most recent call last):
#
#   File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[44], line 2
#     rd_reloaded = raster_loader("Test.drawing")
#
#   Cell In[40], line 17 in raster_loader
#     return eval(f.read())
#
#   File <string>:1
#     RasterDrawing([<__main__.Rectangle object at 0xf51b2c4344a0>])
#                    ^
# SyntaxError: invalid syntax
